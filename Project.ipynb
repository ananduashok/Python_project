# %% [markdown]
# Python_Module_End_Project
#
# As a culminating project, we have a dataset from ABC company, consisting of 458 rows and 9 columns. The company requires a comprehensive report detailing information about their employees across various teams. My tasks include preprocessing the dataset, analyzing the data, and presenting my findings graphically.

# %% [markdown]
# Dataset used: https://docs.google.com/spreadsheets/d/1VP9BE_eI2yl6uUHSm4mGiiwjRdoqCqnkcIjsv5Q2ex4/edit?usp=share_link

# %%
# importing necessary modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading the data

df = pd.read_csv("project.csv")
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
df.describe()
# Out:
#            Number         Age      Weight        Salary
# count  458.000000  458.000000  458.000000  4.470000e+02
# mean    17.713974   26.934498  221.543668  4.833970e+06
# std     15.966837    4.400128   26.343200  5.226620e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.025210e+06
# 50%     13.000000   26.000000  220.000000  2.836186e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
df.College.isnull().sum()
# Out:
# np.int64(84)

# %%
df.Salary.isnull().sum()
# Out:
# np.int64(11)

# %%
# Salary column has null values. Replaced the null values with the mean of the average Salary

df['Salary'] = df.Salary.fillna(df.Salary.mean())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    458 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
# the height values are incorrect, we need to fill it with random numbers between 150 and 180

df['Height'] = np.random.randint(150,181,size=len(df))

# %%
df.head()
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    int32
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    458 non-null    float64
# dtypes: float64(1), int32(1), int64(3), object(4)
# memory usage: 30.5+ KB
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     175     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     172     235
# 2     John Holland  Boston Celtics      30       SG   27     157     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     152     185
# ...

# %% [markdown]
# (1 mark) Analysis Tasks:

# %% [markdown]
# 1. Determine the distribution of employees across each team and calculate the percentage split relative to the total number of employees. (2 marks)

# %%
# calculate the team-wise distribution

team_distribution = df['Team'].value_counts().reset_index()
team_distribution.columns = ['Team','Count']

# calculate percentage split

employee_len = len(df)
team_distribution['Percentage'] = (team_distribution['Count'] / employee_len) * 100
team_distribution
# Out:
#                       Team  Count  Percentage
# 0     New Orleans Pelicans     19    4.148472
# 1        Memphis Grizzlies     18    3.930131
# 2                Utah Jazz     16    3.493450
# 3          Milwaukee Bucks     16    3.493450
# 4          New York Knicks     16    3.493450
# 5           Boston Celtics     15    3.275109
# 6     Los Angeles Clippers     15    3.275109
# 7       Los Angeles Lakers     15    3.275109
# 8             Phoenix Suns     15    3.275109
# 9         Sacramento Kings     15    3.275109
# 10           Brooklyn Nets     15    3.275109
# 11      Philadelphia 76ers     15    3.275109
# 12         Toronto Raptors     15    3.275109
# 13   Golden State Warriors     15    3.275109
# 14          Indiana Pacers     15    3.275109
# 15         Detroit Pistons     15    3.275109
# 16     Cleveland Cavaliers     15    3.275109
# 17           Chicago Bulls     15    3.275109
# 18         Houston Rockets     15    3.275109
# ...

# %%
# Display it visually

plt.figure(figsize=(20,6))

# Normalize the colormap to the number of bars
colors = plt.get_cmap('summer', len(df))(range(len(df)))

bars = plt.bar(
    team_distribution['Team'],
    team_distribution['Count'],
    color = colors
)

# Add percentage labels on top of the bars
for bar, percent in zip(bars, team_distribution['Percentage']):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height() - 2, f'{percent:.1f}%', ha='center', color='white', fontsize=10)

# Customize the plot
plt.title('Employee Distribution by Team (Percentage)', fontsize=16)
plt.xlabel('Team', fontsize=14)
plt.ylabel('Percentage (%)', fontsize=14)
plt.xticks(fontsize=12, rotation=90)
plt.yticks(fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

plt.show()

# %% [markdown]
# 2. Segregate employees based on their positions within the company. (2 marks)

# %%
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     175     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     172     235
# 2   John Holland  Boston Celtics      30       SG   27     157     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     152     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     169     231
#
#              College        Salary
# 0              Texas  7.730337e+06
# 1          Marquette  6.796117e+06
# 2  Boston University  4.833970e+06
# 3      Georgia State  1.148640e+06
# 4                NaN  5.000000e+06

# %%
position_distribution = df['Position'].value_counts().reset_index()
position_distribution.columns = ['Position','Count']
position_distribution
# Out:
#   Position  Count
# 0       SG    102
# 1       PF    100
# 2       PG     92
# 3       SF     85
# 4        C     79

# %%
# Visual representation

plt.figure(figsize = (10,6))
explode = [0.1 if i == position_distribution['Count'].max() else 0.05 for i in position_distribution['Count']]  # Highlight the largest segment

plt.pie(
    position_distribution['Count'],
    labels = position_distribution['Position'],
    autopct='%1.1f%%',
    startangle=10,
    explode=explode,
    shadow = True
)

plt.title('Employee Segregation by Position', fontsize = 15, font = 'Calibri')
plt.tight_layout()
plt.legend(fontsize=8)

plt.show()

# %% [markdown]
# 3. Identify the predominant age group among employees. (2 marks)

# %%
df.head()

# we can use the mode function to get the predominant age group
dominant_age = df.Age.mode()
print("The predominant age group in this data with the most employees is: ",dominant_age[0])
# Out:
# The predominant age group in this data with the most employees is:  24

# %%
age_group = df['Age'].value_counts().reset_index()
age_group.columns=['Age','Count']
age_group['Percentage'] = (age_group['Count']/len(df))*100
age_group
# Out:
#     Age  Count  Percentage
# 0    24     47   10.262009
# 1    25     46   10.043668
# 2    27     41    8.951965
# 3    23     41    8.951965
# 4    26     36    7.860262
# 5    30     31    6.768559
# 6    28     31    6.768559
# 7    29     28    6.113537
# 8    22     26    5.676856
# 9    31     22    4.803493
# 10   21     19    4.148472
# 11   20     19    4.148472
# 12   33     14    3.056769
# 13   32     13    2.838428
# 14   34     10    2.183406
# 15   36     10    2.183406
# 16   35      9    1.965066
# 17   37      4    0.873362
# 18   38      4    0.873362
# 19   40      3    0.655022
# 20   19      2    0.436681
# 21   39      2    0.436681

# %%
# display it visually

plt.figure(figsize=(20,10))
explode = [0.2 if i == age_group['Count'].max() else 0 for i in age_group['Count']]  # Highlight the largest segment

plt.pie(
    age_group['Count'],
    labels = age_group['Age'],
    autopct='%1.1f%%',
    explode = explode
)

plt.title("Predominant Age Group among the Employees")
plt.tight_layout()

plt.show()

# %% [markdown]
# 4. Discover which team and position have the highest salary expenditure. (2 marks)

# %%
# total salary expenditure by team and position

team_salary = df.groupby('Team')['Salary'].sum().reset_index()
position_salary = df.groupby('Position')['Salary'].sum().reset_index()
print(team_salary)
position_salary
# Out:
#                       Team        Salary
# 0            Atlanta Hawks  7.290295e+07
# 1           Boston Celtics  6.337504e+07
# 2            Brooklyn Nets  5.252848e+07
# 3        Charlotte Hornets  7.834092e+07
# 4            Chicago Bulls  8.678338e+07
# 5      Cleveland Cavaliers  1.118227e+08
# 6         Dallas Mavericks  7.119873e+07
# 7           Denver Nuggets  6.495590e+07
# 8          Detroit Pistons  6.716826e+07
# 9    Golden State Warriors  8.886900e+07
# 10         Houston Rockets  7.528302e+07
# 11          Indiana Pacers  6.675183e+07
# 12    Los Angeles Clippers  9.485464e+07
# 13      Los Angeles Lakers  7.177043e+07
# 14       Memphis Grizzlies  9.588676e+07
# 15              Miami Heat  9.218361e+07
# 16         Milwaukee Bucks  6.960352e+07
# 17  Minnesota Timberwolves  6.454367e+07
# 18    New Orleans Pelicans  8.275077e+07
# 19         New York Knicks  7.330390e+07
# 20   Oklahoma City Thunder  9.376530e+07
# 21           Orlando Magic  6.016147e+07
# ...

# %%
# team with highest salary expenditure

highest_team = team_salary.loc[team_salary['Salary'].idxmax()]
print(highest_team)
# Out:
# Team      Cleveland Cavaliers
# Salary       111822658.545861
# Name: 5, dtype: object

# %%
# position with high salary expenditure

highest_position = position_salary.loc[position_salary['Salary'].idxmax()]
highest_position
# Out:
# Position              C
# Salary      466377332.0
# Name: 0, dtype: object

# %%
# visualize

#team salary expenditure

plt.figure(figsize = (10,6))
bars = plt.bar(
    team_salary['Team'],
    team_salary['Salary'],
    color='skyblue',
    edgecolor='black'
)

# Highlight the bar with the highest salary and annotate it
max_team_bar = bars[team_salary['Salary'].idxmax()]
plt.text(max_team_bar.get_x() + max_team_bar.get_width() / 2, max_team_bar.get_height() + 2000,
         f'${highest_team["Salary"]:,.0f}', ha='center', fontsize=12, color='black')

plt.title('Team-wise Salary Expenditure')
plt.xlabel('Team')
plt.ylabel('Salary')
plt.xticks(fontsize=10,rotation=80)
plt.yticks(fontsize=10)
plt.grid(axis='y',linestyle='--',alpha=0.7)
plt.tight_layout()

plt.show()

# %%
# visualize Position wise salary expenditure

plt.figure(figsize = (10,6))

bars = plt.bar(
    position_salary['Position'],
    position_salary['Salary'],
    color='lightgreen',
    edgecolor='black'
)

max_position_bar = bars[position_salary['Salary'].idxmax()]
plt.text(max_position_bar.get_x() + max_position_bar.get_width() / 2, max_position_bar.get_height() + 2000,
         f'${highest_position["Salary"]:,.0f}', ha='center', fontsize=10, color='black')

plt.title('Position-wise Salary Expenditure')
plt.xlabel('Position')
plt.ylabel('Salary')
plt.grid(axis='y',linestyle='--',alpha=0.5)
plt.tight_layout()

plt.show()

# %% [markdown]
# 5. Investigate if there's any correlation between age and salary, and represent it visually.

# %%
# correlation between age and salary

correlation = df['Age'].corr(df['Salary'])
print(f"Correlation between Age and Salary: {correlation:.2f}")
# Out:
# Correlation between Age and Salary: 0.21

# %% [markdown]
# The corr() method calculates the Pearson correlation coefficient between age and salary. A positive correlation means that as age increases, salary tends to increase (and vice versa). Since the correlation is close to 0, we have a positive correaltion but not so strong.

# %%
#visualizing the correlation 

plt.figure(figsize =(10,6))

sns.scatterplot(
    x='Age',
    y='Salary',
    data = df
)

# adding a regression line to show the trend

sns.regplot(
    x='Age',
    y='Salary',
    data=df,
    color='red',
    scatter=False
)

# Customize plot
plt.title('Correlation between Age and Salary', fontsize=16)
plt.xlabel('Age', fontsize=14)
plt.ylabel('Salary ($)', fontsize=14)
plt.grid(True)
plt.tight_layout()

# Show the plot
plt.show()

# %%
print("This is the end of my Project!! Tada!!")
# Out:
# This is the end of my Project!! Tada!!
